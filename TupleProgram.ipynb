# %% [markdown]
# <a href="https://colab.research.google.com/github/2006avni/Python/blob/main/TupleProgram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Create a tuple with three elements: 10, “hello”, and 3.14.
tup = (10, "hello", 3.14)
print(tup)

# %%
# 2. Given the tuple (1, 2, 3, 4, 5), access and print the third element.
tup = (1, 2, 3, 4, 5)
print(tup[2])

# %%
# 3. Concatenate the tuples (1, 2, 3) and (4, 5, 6) and store the result in a new tuple.
tup1 = (1, 2, 3)
tup2 = (4, 5, 6)
new_tup = tup1 + tup2
print(new_tup)

# %%
# 4. Unpack the tuple (a, b, c) into three variables and print their values.
tup = ('a', 'b', 'c')
a, b, c = tup
print(a, b, c)

# %%
# 5. Check if the element 7 exists in the tuple (1, 3, 5, 7, 9).
tup = (1, 3, 5, 7, 9)
print(7 in tup)

# %%
# 6. Create a tuple (0, 1, 2, 3, 4, 5) and print a slice containing elements from index 2 to 4.
tup = (0, 1, 2, 3, 4, 5)
print(tup[2:5])

# %%
# 7. Find the length of the tuple (10, 20, 30, 40, 50).
tup = (10, 20, 30, 40, 50)
print(len(tup))

# %%
# 8. Create a tuple (1, 2, 3) and repeat it three times.
tup = (1, 2, 3)
print(tup * 3)

# %%
# 9. Convert the list [1, 2, 3] to a tuple.
lst = [1, 2, 3]
tup = tuple(lst)
print(tup)

# %%
# 10. Find the minimum and maximum values in the tuple (5, 12, 3, 8, 15).
tup = (5, 12, 3, 8, 15)
print(min(tup), max(tup))

# %%
# 11. Count the number of occurrences of the element 2 in the tuple (1, 2, 3, 2, 4, 2).
tup = (1, 2, 3, 2, 4, 2)
print(tup.count(2))

# %%
# 12. Check if all elements in the tuple (True, True, False) are True.
tup = (True, True, False)
print(all(tup))

# %%
# 13. Find the index of the first occurrence of the element 3 in the tuple (1, 2, 3, 4, 3, 5).
tup = (1, 2, 3, 4, 3, 5)
print(tup.index(3))

# %%
# 14. Sort the elements of the tuple (5, 2, 8, 1, 3) and store the result in a new tuple.
tup = (5, 2, 8, 1, 3)
sorted_tup = tuple(sorted(tup))
print(sorted_tup)

# %%
# 15. Create a tuple containing the squares of numbers from 1 to 5.
tup = tuple(i**2 for i in range(1, 6))
print(tup)

# %%
# 16. Write a Python program to create a tuple.
tup = (1, 2, 3)
print(tup)

# %%
# 17. Write a Python program to create a tuple with different data types.
tup = (10, "hello", 3.14, True)
print(tup)

# %%
# 18. Write a Python program to create a tuple of numbers and print one item.
tup = (10, 20, 30)
print(tup[1])

# %%
# 19. Write a Python program to unpack a tuple into several variables.
tup = (1, 2, 3)
a, b, c = tup
print(a, b, c)

# %%
# 20. Write a Python program to add an item to a tuple.
tup = (1, 2, 3)
tup = tup + (4,)
print(tup)

# %%
# 21. Write a Python program to convert a tuple to a string.
tup = ('p', 'y', 't', 'h', 'o', 'n')
print(''.join(tup))

# %%
# 22. Write a Python program to get the 4th element from the last element of a tuple.
tup = (1, 2, 3, 4, 5, 6, 7, 8)
print(tup[-4])

# %%
# 23. Write a Python program to create the colon of a tuple.
# Note: Tuples do not have a built-in clone method; use copy or assignment.
tup = (1, 2, 3)
tup_copy = tup[:]
print(tup_copy)

# %%
# 24. Write a Python program to find repeated items in a tuple.
tup = (1, 2, 3, 2, 4, 2)
repeated = [x for x in set(tup) if tup.count(x) > 1]
print(repeated)

# %%
# 25. Write a Python program to check whether an element exists within a tuple.
tup = (1, 2, 3)
print(2 in tup)

# %%
# 26. Write a Python program to convert a list to a tuple.
lst = [1, 2, 3]
tup = tuple(lst)
print(tup)

# %%
# 27. Write a Python program to remove an item from a tuple.
# Tuples are immutable; create a new tuple without the item.
tup = (1, 2, 3)
tup = tuple(x for x in tup if x != 2)
print(tup)

# %%
# 28. Write a Python program to slice a tuple.
tup = (0, 1, 2, 3, 4, 5)
print(tup[1:4])

# %%
# 29. Write a Python program to find the index of an item in a tuple.
tup = (10, 20, 30)
print(tup.index(20))

# %%
# 30. Write a Python program to find the length of a tuple.
tup = (1, 2, 3, 4)
print(len(tup))

# %%
# 31. Write a Python program to convert a tuple to a dictionary (assuming tuple of pairs).
tup = (('a', 1), ('b', 2))
d = dict(tup)
print(d)

# %%
# 32. Write a Python program to unzip a list of tuples into individual lists.
lst = [(1, 'a'), (2, 'b'), (3, 'c')]
list1, list2 = zip(*lst)
print(list(list1), list(list2))

# %%
# 33. Write a Python program to reverse a tuple.
tup = (1, 2, 3, 4)
print(tup[::-1])

# %%
# 34. Write a Python program to convert a list of tuples into a dictionary.
lst = [('a', 1), ('b', 2), ('c', 3)]
d = dict(lst)
print(d)

# %%
# 35. Write a Python program to remove an empty tuple(s) from a list of tuples.
lst = [(), ('a', 'b'), ('a', 'b', 'c'), ('d',)]
filtered = [t for t in lst if t]
print(filtered)

# %%
# 36. Write a Python program to convert a given string list to a tuple.
string = "python 3.0"
tup = tuple(string)
print(tup)
